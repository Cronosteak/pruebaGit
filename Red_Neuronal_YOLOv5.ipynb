# %% [markdown]
# <a href="https://colab.research.google.com/github/Cronosteak/pruebaGit/blob/main/Red_Neuronal_YOLOv5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div align="center">
#
#   <a href="https://ultralytics.com/yolov5" target="_blank">
#     <img width="1024", src="https://raw.githubusercontent.com/ultralytics/assets/main/yolov5/v70/splash.png"></a>
#
# [中文](https://docs.ultralytics.com/zh/) | [한국어](https://docs.ultralytics.com/ko/) | [日本語](https://docs.ultralytics.com/ja/) | [Русский](https://docs.ultralytics.com/ru/) | [Deutsch](https://docs.ultralytics.com/de/) | [Français](https://docs.ultralytics.com/fr/) | [Español](https://docs.ultralytics.com/es/) | [Português](https://docs.ultralytics.com/pt/) | [हिन्दी](https://docs.ultralytics.com/hi/) | [العربية](https://docs.ultralytics.com/ar/)
#
#   <a href="https://bit.ly/yolov5-paperspace-notebook"><img src="https://assets.paperspace.io/img/gradient-badge.svg" alt="Run on Gradient"></a>
#   <a href="https://colab.research.google.com/github/ultralytics/yolov5/blob/master/tutorial.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a>
#   <a href="https://www.kaggle.com/ultralytics/yolov5"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" alt="Open In Kaggle"></a>
#
# This <a href="https://github.com/ultralytics/yolov5">YOLOv5</a> 🚀 notebook by <a href="https://ultralytics.com">Ultralytics</a> presents simple train, validate and predict examples to help start your AI adventure.<br>We hope that the resources in this notebook will help you get the most out of YOLOv5. Please browse the YOLOv5 <a href="https://docs.ultralytics.com/yolov5">Docs</a> for details, raise an issue on <a href="https://github.com/ultralytics/yolov5">GitHub</a> for support, and join our <a href="https://ultralytics.com/discord">Discord</a> community for questions and discussions!
#
# </div>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Setup
#
# Clone GitHub [repository](https://github.com/ultralytics/yolov5), install [dependencies](https://github.com/ultralytics/yolov5/blob/master/requirements.txt) and check PyTorch and GPU.

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt comet_ml  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-294-gdb125a20 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# Setup complete ✅ (8 CPUs, 51.0 GB RAM, 29.0/201.2 GB disk)

# %%
# !unzip -q /content/data.zip -d /content/

# %% [markdown]
# # 1. Detect
#
# `detect.py` runs YOLOv5 inference on a variety of sources, downloading models automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases), and saving results to `runs/detect`. Example inference sources are:
#
# ```shell
# python detect.py --source 0  # webcam
#                           img.jpg  # image
#                           vid.mp4  # video
#                           screen  # screenshot
#                           path/  # directory
#                          'path/*.jpg'  # glob
#                          'https://youtu.be/LNwODJXcvt4'  # YouTube
#                          'rtsp://example.com/media.mp4'  # RTSP, RTMP, HTTP stream
# ```

# %%
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source data/images
# display.Image(filename='runs/detect/exp/zidane.jpg', width=600)
# Out:
# detect: weights=['yolov5s.pt'], source=data/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-136-g71244ae Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s.pt to yolov5s.pt...
# 100% 14.1M/14.1M [00:00<00:00, 24.5MB/s]
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# image 1/2 /content/yolov5/data/images/bus.jpg: 640x480 4 persons, 1 bus, 41.5ms
# image 2/2 /content/yolov5/data/images/zidane.jpg: 384x640 2 persons, 2 ties, 60.0ms
# Speed: 0.5ms pre-process, 50.8ms inference, 37.7ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img align="left" src="https://user-images.githubusercontent.com/26833433/127574988-6a558aa1-d268-44b9-bf6b-62d4c605cc72.jpg" width="600">

# %% [markdown]
# # 2. Validate
# Validate a model's accuracy on the [COCO](https://cocodataset.org/#home) dataset's `val` or `test` splits. Models are downloaded automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases). To show results by class use the `--verbose` flag.

# %%
# Download COCO val
torch.hub.download_url_to_file('https://ultralytics.com/assets/coco2017val.zip', 'tmp.zip')  # download (780M - 5000 images)
# !unzip -q tmp.zip -d ../datasets && rm tmp.zip  # unzip
# Out:
# 100%|██████████| 780M/780M [00:12<00:00, 66.6MB/s]

# %%
# Validate YOLOv5s on COCO val
# !python val.py --weights yolov5s.pt --data coco.yaml --img 640 --half
# Out:
# val: data=/content/yolov5/data/coco.yaml, weights=['yolov5s.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=True, project=runs/val, name=exp, exist_ok=False, half=True, dnn=False
# YOLOv5 🚀 v7.0-136-g71244ae Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# val: Scanning /content/datasets/coco/val2017... 4952 images, 48 backgrounds, 0 corrupt: 100% 5000/5000 [00:02<00:00, 2024.59it/s]
# val: New cache created: /content/datasets/coco/val2017.cache
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 157/157 [01:25<00:00,  1.84it/s]
#                    all       5000      36335      0.671      0.519      0.566      0.371
# Speed: 0.1ms pre-process, 3.1ms inference, 2.3ms NMS per image at shape (32, 3, 640, 640)
#
# Evaluating pycocotools mAP... saving runs/val/exp/yolov5s_predictions.json...
# loading annotations into memory...
# Done (t=0.43s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=5.32s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=78.89s).
# Accumulating evaluation results...
# DONE (t=14.51s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.374
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.572
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.402
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.211
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.423
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.489
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.311
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.516
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.566
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.378
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.625
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.722
# Results saved to runs/val/exp

# %% [markdown]
# # 3. Train
#
# <p align=""><a href="https://bit.ly/ultralytics_hub"><img width="1000" src="https://github.com/ultralytics/assets/raw/main/im/integrations-loop.png"/></a></p>
# Close the active learning loop by sampling images from your inference conditions with the `roboflow` pip package
# <br><br>
#
# Train a YOLOv5s model on the [COCO128](https://www.kaggle.com/ultralytics/coco128) dataset with `--data coco128.yaml`, starting from pretrained `--weights yolov5s.pt`, or from randomly initialized `--weights '' --cfg yolov5s.yaml`.
#
# - **Pretrained [Models](https://github.com/ultralytics/yolov5/tree/master/models)** are downloaded
# automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases)
# - **[Datasets](https://github.com/ultralytics/yolov5/tree/master/data)** available for autodownload include: [COCO](https://github.com/ultralytics/yolov5/blob/master/data/coco.yaml), [COCO128](https://github.com/ultralytics/yolov5/blob/master/data/coco128.yaml), [VOC](https://github.com/ultralytics/yolov5/blob/master/data/VOC.yaml), [Argoverse](https://github.com/ultralytics/yolov5/blob/master/data/Argoverse.yaml), [VisDrone](https://github.com/ultralytics/yolov5/blob/master/data/VisDrone.yaml), [GlobalWheat](https://github.com/ultralytics/yolov5/blob/master/data/GlobalWheat2020.yaml), [xView](https://github.com/ultralytics/yolov5/blob/master/data/xView.yaml), [Objects365](https://github.com/ultralytics/yolov5/blob/master/data/Objects365.yaml), [SKU-110K](https://github.com/ultralytics/yolov5/blob/master/data/SKU-110K.yaml).
# - **Training Results** are saved to `runs/train/` with incrementing run directories, i.e. `runs/train/exp2`, `runs/train/exp3` etc.
# <br>
#
# A **Mosaic Dataloader** is used for training which combines 4 images into 1 mosaic.
#
# ## Label a dataset on Roboflow (optional)
#
# [Roboflow](https://roboflow.com/?ref=ultralytics) enables you to easily **organize, label, and prepare** a high quality dataset with your own custom data. Roboflow also makes it easy to establish an active learning pipeline, collaborate with your team on dataset improvement, and integrate directly into your model building workflow with the `roboflow` pip package.

# %%
#@title Select YOLOv5 🚀 logger {run: 'auto'}
logger = 'Comet' #@param ['Comet', 'ClearML', 'TensorBoard']

if logger == 'Comet':
  # %pip install -q comet_ml
  import comet_ml; comet_ml.init()
elif logger == 'ClearML':
  # %pip install -q clearml
  import clearml; clearml.browser_login()
elif logger == 'TensorBoard':
  # %load_ext tensorboard
  # %tensorboard --logdir runs/train

# %%
# Train YOLOv5s on COCO128 for 3 epochs
# !python train.py --img 640 --batch 4 --epochs 100 --data /content/yolov5/data/Prueba.yaml --weights yolov5x.pt --cache
# Out:
# 2024-03-22 03:00:02.692983: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-22 03:00:02.693082: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-22 03:00:02.827184: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# train: weights=yolov5x.pt, cfg=, data=/content/yolov5/data/Prueba.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=4, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data/hyps, resume_evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-294-gdb125a20 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# COMET WARNING: Comet credentials have not been set. Comet will default to offline logging. Please set your credentials to enable online logging.
# COMET INFO: Using '/content/yolov5/.cometml-runs' path as offline directory. Pass 'offline_directory' parameter into constructor or set the 'COMET_OFFLINE_DIRECTORY' environment variable to manually choose where to store offline experiment archives.
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5x.pt to yolov5x.pt...
# 100%|██████████| 166M/166M [00:00<00:00, 355MB/s]
#
# Overriding model.yaml nc=80 with nc=3
#
#                  from  n    params  module                                  arguments
#   0                -1  1      8800  models.common.Conv                      [3, 80, 6, 2, 2]
#   1                -1  1    115520  models.common.Conv                      [80, 160, 3, 2]
#   2                -1  4    309120  models.common.C3                        [160, 160, 4]
#   3                -1  1    461440  models.common.Conv                      [160, 320, 3, 2]
#   4                -1  8   2259200  models.common.C3                        [320, 320, 8]
#   5                -1  1   1844480  models.common.Conv                      [320, 640, 3, 2]
#   6                -1 12  13125120  models.common.C3                        [640, 640, 12]
#   7                -1  1   7375360  models.common.Conv                      [640, 1280, 3, 2]
#   8                -1  4  19676160  models.common.C3                        [1280, 1280, 4]
#   9                -1  1   4099840  models.common.SPPF                      [1280, 1280, 5]
#  10                -1  1    820480  models.common.Conv                      [1280, 640, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  4   5332480  models.common.C3                        [1280, 640, 4, False]
#  14                -1  1    205440  models.common.Conv                      [640, 320, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  4   1335040  models.common.C3                        [640, 320, 4, False]
#  18                -1  1    922240  models.common.Conv                      [320, 320, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  4   4922880  models.common.C3                        [640, 640, 4, False]
#  21                -1  1   3687680  models.common.Conv                      [640, 640, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  4  19676160  models.common.C3                        [1280, 1280, 4, False]
#  24      [17, 20, 23]  1     53832  models.yolo.Detect                      [3, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [320, 640, 1280]]
# Model summary: 445 layers, 86231272 parameters, 86231272 gradients, 204.7 GFLOPs
#
# Transferred 739/745 items from yolov5x.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 123 weight(decay=0.0), 126 weight(decay=0.0005), 126 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# train: Scanning /content/data/labels/train... 1957 images, 0 backgrounds, 0 corrupt: 100%|██████████| 1957/1957 [02:26<00:00, 13.39it/s]
# train: WARNING ⚠️ /content/data/images/train/20240319_173656_013.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173656_014.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173656_015.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173656_016.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173656_017.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173656_018.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173656_019.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173656_020.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173656_021.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173656_022.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173656_023.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173656_024.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173656_025.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173656_026.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173656_027.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173656_028.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173656_029.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173656_030.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173709_001.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173709_002.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173709_003.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173709_004.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173709_005.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173709_006.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173709_007.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173709_008.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173709_009.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173709_010.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173709_011.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173709_012.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173709_013.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173709_014.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173709_015.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173709_016.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173709_017.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173709_018.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173709_019.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173709_020.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173709_021.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173709_022.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173709_023.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173709_024.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173720_023.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173720_024.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173720_025.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173720_026.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173720_027.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173720_028.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173720_029.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173720_030.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173732_001.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173732_002.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173732_003.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173732_004.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173732_005.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173732_006.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173732_007.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173732_008.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173732_009.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173732_010.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173732_011.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173732_012.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173732_013.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173732_014.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173732_015.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173732_016.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173732_017.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173732_018.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173732_019.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173732_020.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173732_021.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173732_022.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173732_023.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173732_024.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173732_025.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173732_026.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173732_027.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173732_028.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173732_029.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173732_030.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173742_001.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173742_002.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173742_003.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173742_004.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173742_005.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173742_006.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173742_007.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173742_008.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173742_009.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173742_010.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173742_011.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173742_012.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173742_013.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173742_014.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173742_015.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173742_016.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173742_017.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173742_018.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173742_019.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173742_020.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173742_021.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173742_022.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173742_023.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173742_024.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173742_025.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173742_026.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173742_027.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173742_028.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173742_029.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173742_030.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173803_001.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173803_002.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173803_003.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173803_004.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173803_005.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173803_006.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173803_007.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173803_008.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173803_009.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173803_010.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173803_011.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173803_012.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173803_013.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173803_014.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173803_015.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_173803_016.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174034_025.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174034_026.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174034_027.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174034_028.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174034_029.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174034_030.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174749_001.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174749_002.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174749_003.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174749_004.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174749_005.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174749_006.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174749_007.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174749_008.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174749_009.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174749_010.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174749_011.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174749_012.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174749_013.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174749_014.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174749_015.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174749_016.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174749_017.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174749_018.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174749_019.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174749_020.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174749_021.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174749_022.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174749_023.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174749_024.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174749_025.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174749_026.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174749_027.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174749_028.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174749_029.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174749_030.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174801_001.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174801_002.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174801_003.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174801_004.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174801_005.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174801_006.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174801_007.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174801_008.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174801_009.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174801_010.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174801_011.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174801_012.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174801_013.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174801_014.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174801_015.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174801_016.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174801_017.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174801_018.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174825_019.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174825_020.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174825_021.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174825_022.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174825_023.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174825_024.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174825_025.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174825_026.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174825_027.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174825_028.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174825_029.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174825_030.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174844_001.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174844_002.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174844_003.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174844_004.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174844_005.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174844_006.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174844_007.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174844_008.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174844_009.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174844_010.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174844_011.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174844_012.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174908_019.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174908_020.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174908_021.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174908_022.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174908_023.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174908_024.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174908_025.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174908_026.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174908_027.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174908_028.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174908_029.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174908_030.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174954_001.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174954_002.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174954_003.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174954_004.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174954_005.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174954_006.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174954_007.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174954_008.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174954_009.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174954_010.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174954_011.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174954_012.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174954_013.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174954_014.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174954_015.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174954_016.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174954_017.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_174954_018.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175013_009.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175013_010.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175013_011.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175013_012.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175013_013.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175013_014.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175013_015.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175013_016.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175013_017.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175013_018.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175013_019.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175013_020.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175013_021.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175013_022.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175013_023.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175013_024.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175013_025.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175013_026.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175013_027.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175013_028.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175013_029.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175013_030.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175127_001.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175127_002.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175127_003.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175127_004.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175127_005.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175127_006.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175127_007.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175127_008.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175127_009.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175127_010.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175127_011.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175127_012.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175127_013.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175127_014.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175127_015.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175127_016.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175127_017.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175127_018.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175127_019.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175127_020.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175127_021.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175127_022.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175127_023.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175127_024.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175127_025.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175127_026.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175140_018.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175140_019.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175140_020.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175140_021.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175140_022.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175140_023.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175140_024.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175140_025.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175140_026.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175140_027.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175140_028.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175140_029.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175140_030.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175153_001.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175153_002.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175153_003.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175153_004.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175153_005.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175153_006.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175153_007.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175153_008.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175153_009.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175153_010.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175153_011.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175153_012.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175153_013.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175153_014.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175153_015.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175153_016.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175153_017.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175153_018.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175153_019.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175153_020.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175153_021.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175153_022.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175153_023.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175153_024.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175153_025.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175153_026.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175153_027.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175153_028.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175153_029.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175153_030.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175206_001.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175206_002.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175206_003.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175206_004.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175206_005.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175206_006.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175206_007.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175206_008.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175206_009.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175206_010.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175206_011.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175206_012.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175206_013.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175206_014.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175206_015.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175206_016.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175206_017.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175206_018.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175206_019.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175206_020.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175206_021.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175206_022.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175206_023.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175206_024.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175206_025.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175206_026.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175206_027.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175455_001.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175455_002.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175455_003.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175455_004.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175455_005.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175455_006.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175455_007.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175455_008.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175455_009.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175455_010.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175455_011.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175455_012.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175455_013.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175455_014.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175455_015.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175455_016.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175455_017.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175455_018.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175455_019.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175455_020.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175619_001.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175619_002.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175619_003.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175619_004.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175619_005.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175619_006.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175619_007.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175619_008.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175619_009.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175619_010.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175619_011.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175619_012.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175619_013.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175619_014.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175619_015.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175619_016.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175619_017.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175619_018.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175619_019.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175619_020.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175619_021.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175619_022.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175619_023.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175619_024.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175619_025.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175619_026.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175619_027.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175619_028.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175619_029.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175619_030.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175633_001.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175633_002.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175633_003.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175633_004.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175633_005.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175633_006.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175633_007.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175633_008.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175633_009.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/data/images/train/20240319_175633_010.jpg: corrupt JPEG restored and saved
# ...
#                    all        781        781      0.965      0.965      0.964      0.507
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       81/99      5.64G    0.03008   0.008063  6.699e-05          1        640: 100%|██████████| 490/490 [01:08<00:00,  7.20it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 98/98 [00:10<00:00,  9.51it/s]
#                    all        781        781      0.965      0.965      0.966      0.514
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       82/99      5.64G     0.0297   0.007983  6.206e-05          1        640: 100%|██████████| 490/490 [01:08<00:00,  7.20it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 98/98 [00:10<00:00,  9.59it/s]
#                    all        781        781      0.964      0.964      0.966      0.502
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       83/99      5.64G    0.02946   0.008046  7.521e-05          3        640: 100%|██████████| 490/490 [01:09<00:00,  7.10it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 98/98 [00:10<00:00,  9.26it/s]
#                    all        781        781      0.965      0.965      0.967      0.506
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       84/99      5.64G    0.02978   0.007974  6.058e-05          4        640: 100%|██████████| 490/490 [01:08<00:00,  7.15it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 98/98 [00:10<00:00,  9.54it/s]
#                    all        781        781      0.963      0.963      0.965       0.51
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       85/99      5.64G    0.02958    0.00797  5.886e-05          1        640: 100%|██████████| 490/490 [01:08<00:00,  7.18it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 98/98 [00:10<00:00,  9.50it/s]
#                    all        781        781      0.963      0.963      0.965      0.499
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       86/99      5.64G    0.02891   0.007985  5.656e-05          3        640: 100%|██████████| 490/490 [01:08<00:00,  7.19it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 98/98 [00:10<00:00,  9.51it/s]
#                    all        781        781      0.963      0.963      0.962      0.507
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       87/99      5.64G    0.02938   0.007823  5.578e-05          2        640: 100%|██████████| 490/490 [01:08<00:00,  7.20it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 98/98 [00:10<00:00,  9.60it/s]
#                    all        781        781      0.968      0.968      0.965      0.503
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       88/99      5.64G    0.02874   0.007907  5.489e-05          1        640: 100%|██████████| 490/490 [01:08<00:00,  7.16it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 98/98 [00:10<00:00,  9.47it/s]
#                    all        781        781      0.967      0.967      0.965      0.511
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       89/99      5.64G    0.02911   0.007978  5.401e-05          1        640: 100%|██████████| 490/490 [01:08<00:00,  7.12it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 98/98 [00:10<00:00,  9.43it/s]
#                    all        781        781      0.967      0.967      0.966      0.503
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       90/99      5.64G      0.029   0.007859  5.485e-05          1        640: 100%|██████████| 490/490 [01:08<00:00,  7.19it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 98/98 [00:10<00:00,  9.48it/s]
#                    all        781        781      0.963      0.963      0.965      0.507
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       91/99      5.64G    0.02884   0.007914  4.997e-05          1        640: 100%|██████████| 490/490 [01:08<00:00,  7.17it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 98/98 [00:10<00:00,  9.52it/s]
#                    all        781        781      0.961      0.962      0.967      0.503
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       92/99      5.64G    0.02853   0.007803  4.793e-05          2        640: 100%|██████████| 490/490 [01:08<00:00,  7.20it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 98/98 [00:10<00:00,  9.46it/s]
#                    all        781        781      0.967      0.967      0.966      0.507
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       93/99      5.64G    0.02857    0.00799  5.165e-05          4        640: 100%|██████████| 490/490 [01:08<00:00,  7.14it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 98/98 [00:10<00:00,  9.34it/s]
#                    all        781        781      0.965      0.965      0.965       0.51
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       94/99      5.64G    0.02836   0.007853  4.771e-05          0        640: 100%|██████████| 490/490 [01:08<00:00,  7.14it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 98/98 [00:10<00:00,  9.43it/s]
#                    all        781        781      0.969      0.969       0.97      0.511
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       95/99      5.64G    0.02872   0.007792  4.615e-05          1        640: 100%|██████████| 490/490 [01:08<00:00,  7.13it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 98/98 [00:10<00:00,  9.38it/s]
#                    all        781        781      0.969      0.969       0.97      0.506
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       96/99      5.64G    0.02827   0.007969  4.566e-05          1        640: 100%|██████████| 490/490 [01:08<00:00,  7.11it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 98/98 [00:10<00:00,  9.43it/s]
#                    all        781        781      0.968      0.968      0.968      0.511
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       97/99      5.64G    0.02825   0.007852   4.45e-05          3        640: 100%|██████████| 490/490 [01:09<00:00,  7.09it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 98/98 [00:10<00:00,  9.29it/s]
#                    all        781        781      0.967      0.967      0.967       0.51
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       98/99      5.64G    0.02817   0.007751  4.421e-05          1        640: 100%|██████████| 490/490 [01:08<00:00,  7.15it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 98/98 [00:10<00:00,  9.49it/s]
#                    all        781        781      0.969      0.969      0.967      0.506
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       99/99      5.64G    0.02801   0.007864  4.405e-05          1        640: 100%|██████████| 490/490 [01:08<00:00,  7.15it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 98/98 [00:10<00:00,  9.47it/s]
#                    all        781        781      0.968      0.968      0.968      0.507
#
# 100 epochs completed in 2.242 hours.
# Optimizer stripped from runs/train/exp/weights/last.pt, 173.1MB
# Optimizer stripped from runs/train/exp/weights/best.pt, 173.1MB
#
# Validating runs/train/exp/weights/best.pt...
# Fusing layers...
# Model summary: 322 layers, 86186872 parameters, 0 gradients, 203.8 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 98/98 [00:11<00:00,  8.57it/s]
#                    all        781        781      0.981      0.981      0.985      0.527
#               Cuadrado        781        781      0.981      0.981      0.985      0.527
# Results saved to runs/train/exp
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml OfflineExperiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : [OfflineExperiment will get URL after upload]
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     loss [4810]                : (0.03417982906103134, 0.7034987211227417)
# COMET INFO:     metrics/mAP_0.5 [200]      : (0.49791434879167945, 0.9849578915874779)
# COMET INFO:     metrics/mAP_0.5:0.95 [200] : (0.1829188527043828, 0.5274913505278324)
# COMET INFO:     metrics/precision [200]    : (0.45186654551667854, 0.9805959363254264)
# COMET INFO:     metrics/recall [200]       : (0.793854033290653, 0.9807938540332907)
# COMET INFO:     train/box_loss [200]       : (0.028008848428726196, 0.07135625183582306)
# COMET INFO:     train/cls_loss [200]       : (4.40474359493237e-05, 0.01113517489284277)
# COMET INFO:     train/obj_loss [200]       : (0.007750587072223425, 0.022106124088168144)
# COMET INFO:     val/box_loss [200]         : (0.03208620846271515, 0.05337601155042648)
# COMET INFO:     val/cls_loss [200]         : (1.3477909305947833e-05, 0.002292476361617446)
# COMET INFO:     val/obj_loss [200]         : (0.005826062057167292, 0.008533008396625519)
# COMET INFO:     x/lr0 [200]                : (0.0002980000000000002, 0.07006122448979592)
# COMET INFO:     x/lr1 [200]                : (0.0002980000000000002, 0.009795331972789116)
# COMET INFO:     x/lr2 [200]                : (0.0002980000000000002, 0.009795331972789116)
# COMET INFO:   Others:
# COMET INFO:     Name                        : exp
# COMET INFO:     comet_log_batch_metrics     : False
# COMET INFO:     comet_log_confusion_matrix  : True
# COMET INFO:     comet_log_per_class_metrics : False
# COMET INFO:     comet_max_image_uploads     : 100
# COMET INFO:     comet_mode                  : online
# COMET INFO:     comet_model_name            : yolov5
# COMET INFO:     hasNestedParams             : True
# COMET INFO:     offline_experiment          : True
# COMET INFO:   Parameters:
# COMET INFO:     anchor_t            : 4.0
# COMET INFO:     artifact_alias      : latest
# COMET INFO:     batch_size          : 4
# COMET INFO:     bbox_interval       : -1
# COMET INFO:     box                 : 0.05
# COMET INFO:     bucket              :
# COMET INFO:     cfg                 :
# COMET INFO:     cls                 : 0.01875
# COMET INFO:     cls_pw              : 1.0
# COMET INFO:     copy_paste          : 0.0
# COMET INFO:     cos_lr              : False
# COMET INFO:     degrees             : 0.0
# COMET INFO:     device              :
# COMET INFO:     entity              : None
# COMET INFO:     evolve              : None
# COMET INFO:     evolve_population   : data/hyps
# COMET INFO:     exist_ok            : False
# COMET INFO:     fl_gamma            : 0.0
# COMET INFO:     fliplr              : 0.5
# COMET INFO:     flipud              : 0.0
# COMET INFO:     freeze              : [0]
# COMET INFO:     hsv_h               : 0.015
# COMET INFO:     hsv_s               : 0.7
# COMET INFO:     hsv_v               : 0.4
# COMET INFO:     hyp|anchor_t        : 4.0
# COMET INFO:     hyp|box             : 0.05
# COMET INFO:     hyp|cls             : 0.5
# COMET INFO:     hyp|cls_pw          : 1.0
# COMET INFO:     hyp|copy_paste      : 0.0
# COMET INFO:     hyp|degrees         : 0.0
# COMET INFO:     hyp|fl_gamma        : 0.0
# COMET INFO:     hyp|fliplr          : 0.5
# COMET INFO:     hyp|flipud          : 0.0
# COMET INFO:     hyp|hsv_h           : 0.015
# COMET INFO:     hyp|hsv_s           : 0.7
# COMET INFO:     hyp|hsv_v           : 0.4
# COMET INFO:     hyp|iou_t           : 0.2
# COMET INFO:     hyp|lr0             : 0.01
# COMET INFO:     hyp|lrf             : 0.01
# COMET INFO:     hyp|mixup           : 0.0
# COMET INFO:     hyp|momentum        : 0.937
# COMET INFO:     hyp|mosaic          : 1.0
# COMET INFO:     hyp|obj             : 1.0
# COMET INFO:     hyp|obj_pw          : 1.0
# COMET INFO:     hyp|perspective     : 0.0
# COMET INFO:     hyp|scale           : 0.5
# COMET INFO:     hyp|shear           : 0.0
# COMET INFO:     hyp|translate       : 0.1
# COMET INFO:     hyp|warmup_bias_lr  : 0.1
# COMET INFO:     hyp|warmup_epochs   : 3.0
# COMET INFO:     hyp|warmup_momentum : 0.8
# COMET INFO:     hyp|weight_decay    : 0.0005
# COMET INFO:     image_weights       : False
# COMET INFO:     imgsz               : 640
# COMET INFO:     iou_t               : 0.2
# COMET INFO:     label_smoothing     : 0.0
# COMET INFO:     local_rank          : -1
# COMET INFO:     lr0                 : 0.01
# COMET INFO:     lrf                 : 0.01
# COMET INFO:     mixup               : 0.0
# COMET INFO:     momentum            : 0.937
# COMET INFO:     mosaic              : 1.0
# COMET INFO:     multi_scale         : False
# COMET INFO:     name                : exp
# COMET INFO:     ndjson_console      : False
# COMET INFO:     ndjson_file         : False
# COMET INFO:     noautoanchor        : False
# COMET INFO:     noplots             : False
# COMET INFO:     nosave              : False
# COMET INFO:     noval               : False
# COMET INFO:     obj                 : 1.0
# COMET INFO:     obj_pw              : 1.0
# COMET INFO:     optimizer           : SGD
# COMET INFO:     patience            : 100
# COMET INFO:     perspective         : 0.0
# COMET INFO:     project             : runs/train
# COMET INFO:     quad                : False
# COMET INFO:     rect                : False
# COMET INFO:     resume              : False
# COMET INFO:     resume_evolve       : None
# COMET INFO:     save_dir            : runs/train/exp
# COMET INFO:     save_period         : -1
# COMET INFO:     scale               : 0.5
# COMET INFO:     seed                : 0
# COMET INFO:     shear               : 0.0
# COMET INFO:     single_cls          : False
# COMET INFO:     sync_bn             : False
# COMET INFO:     translate           : 0.1
# COMET INFO:     upload_dataset      : False
# COMET INFO:     val_conf_threshold  : 0.001
# COMET INFO:     val_iou_threshold   : 0.6
# COMET INFO:     warmup_bias_lr      : 0.1
# COMET INFO:     warmup_epochs       : 3.0
# COMET INFO:     warmup_momentum     : 0.8
# COMET INFO:     weight_decay        : 0.0005
# COMET INFO:     workers             : 8
# COMET INFO:   Uploads:
# COMET INFO:     asset               : 13 (1.08 MB)
# COMET INFO:     confusion-matrix    : 1
# COMET INFO:     environment details : 1
# COMET INFO:     git metadata        : 1
# COMET INFO:     images              : 6
# COMET INFO:     installed packages  : 1
# COMET INFO:     model graph         : 1
# COMET INFO:     os packages         : 1
# COMET INFO:
# COMET INFO: Still saving offline stats to messages file before program termination (may take up to 120 seconds)
# COMET INFO: Starting saving the offline archive
# COMET INFO: To upload this offline experiment, run:
#     comet upload /content/yolov5/.cometml-runs/8dfb59330d3740c6bb85ba52e329c296.zip

# %% [markdown]
# # 4. Visualize

# %% [markdown]
# ## Comet Logging and Visualization 🌟 NEW
#
# [Comet](https://www.comet.com/site/lp/yolov5-with-comet/?utm_source=yolov5&utm_medium=partner&utm_campaign=partner_yolov5_2022&utm_content=yolov5_colab) is now fully integrated with YOLOv5. Track and visualize model metrics in real time, save your hyperparameters, datasets, and model checkpoints, and visualize your model predictions with [Comet Custom Panels](https://www.comet.com/docs/v2/guides/comet-dashboard/code-panels/about-panels/?utm_source=yolov5&utm_medium=partner&utm_campaign=partner_yolov5_2022&utm_content=yolov5_colab)! Comet makes sure you never lose track of your work and makes it easy to share results and collaborate across teams of all sizes!
#
# Getting started is easy:
# ```shell
# pip install comet_ml  # 1. install
# export COMET_API_KEY=<Your API Key>  # 2. paste API key
# python train.py --img 640 --epochs 3 --data coco128.yaml --weights yolov5s.pt  # 3. train
# ```
# To learn more about all of the supported Comet features for this integration, check out the [Comet Tutorial](https://docs.ultralytics.com/yolov5/tutorials/comet_logging_integration). If you'd like to learn more about Comet, head over to our [documentation](https://www.comet.com/docs/v2/?utm_source=yolov5&utm_medium=partner&utm_campaign=partner_yolov5_2022&utm_content=yolov5_colab). Get started by trying out the Comet Colab Notebook:
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1RG0WOQyxlDlo5Km8GogJpIEJlg_5lyYO?usp=sharing)
#
# <a href="https://bit.ly/yolov5-readme-comet2">
# <img alt="Comet Dashboard" src="https://user-images.githubusercontent.com/26833433/202851203-164e94e1-2238-46dd-91f8-de020e9d6b41.png" width="1280"/></a>

# %%
from google.colab import files
files.download('./runs/train/exp/weights/best.pt')

# %% [markdown]
# ## ClearML Logging and Automation 🌟 NEW
#
# [ClearML](https://cutt.ly/yolov5-notebook-clearml) is completely integrated into YOLOv5 to track your experimentation, manage dataset versions and even remotely execute training runs. To enable ClearML (check cells above):
#
# - `pip install clearml`
# - run `clearml-init` to connect to a ClearML server (**deploy your own [open-source server](https://github.com/allegroai/clearml-server)**, or use our [free hosted server](https://cutt.ly/yolov5-notebook-clearml))
#
# You'll get all the great expected features from an experiment manager: live updates, model upload, experiment comparison etc. but ClearML also tracks uncommitted changes and installed packages for example. Thanks to that ClearML Tasks (which is what we call experiments) are also reproducible on different machines! With only 1 extra line, we can schedule a YOLOv5 training task on a queue to be executed by any number of ClearML Agents (workers).
#
# You can use ClearML Data to version your dataset and then pass it to YOLOv5 simply using its unique ID. This will help you keep track of your data without adding extra hassle. Explore the [ClearML Tutorial](https://docs.ultralytics.com/yolov5/tutorials/clearml_logging_integration) for details!
#
# <a href="https://cutt.ly/yolov5-notebook-clearml">
# <img alt="ClearML Experiment Management UI" src="https://github.com/thepycoder/clearml_screenshots/raw/main/scalars.jpg" width="1280"/></a>

# %% [markdown]
# ## Local Logging
#
# Training results are automatically logged with [Tensorboard](https://www.tensorflow.org/tensorboard) and [CSV](https://github.com/ultralytics/yolov5/pull/4148) loggers to `runs/train`, with a new experiment directory created for each new training as `runs/train/exp2`, `runs/train/exp3`, etc.
#
# This directory contains train and val statistics, mosaics, labels, predictions and augmentated mosaics, as well as metrics and charts including precision-recall (PR) curves and confusion matrices.
#
# <img alt="Local logging results" src="https://user-images.githubusercontent.com/26833433/183222430-e1abd1b7-782c-4cde-b04d-ad52926bf818.jpg" width="1280"/>

# %% [markdown]
# # Environments
#
# YOLOv5 may be run in any of the following up-to-date verified environments (with all dependencies including [CUDA](https://developer.nvidia.com/cuda)/[CUDNN](https://developer.nvidia.com/cudnn), [Python](https://www.python.org/) and [PyTorch](https://pytorch.org/) preinstalled):
#
# - **Notebooks** with free GPU: <a href="https://bit.ly/yolov5-paperspace-notebook"><img src="https://assets.paperspace.io/img/gradient-badge.svg" alt="Run on Gradient"></a> <a href="https://colab.research.google.com/github/ultralytics/yolov5/blob/master/tutorial.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a> <a href="https://www.kaggle.com/ultralytics/yolov5"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" alt="Open In Kaggle"></a>
# - **Google Cloud** Deep Learning VM. See [GCP Quickstart Guide](https://docs.ultralytics.com/yolov5/environments/google_cloud_quickstart_tutorial/)
# - **Amazon** Deep Learning AMI. See [AWS Quickstart Guide](https://docs.ultralytics.com/yolov5/environments/aws_quickstart_tutorial/)
# - **Docker Image**. See [Docker Quickstart Guide](https://docs.ultralytics.com/yolov5/environments/docker_image_quickstart_tutorial/) <a href="https://hub.docker.com/r/ultralytics/yolov5"><img src="https://img.shields.io/docker/pulls/ultralytics/yolov5?logo=docker" alt="Docker Pulls"></a>

# %% [markdown]
# # Status
#
# ![YOLOv5 CI](https://github.com/ultralytics/yolov5/actions/workflows/ci-testing.yml/badge.svg)
#
# If this badge is green, all [YOLOv5 GitHub Actions](https://github.com/ultralytics/yolov5/actions) Continuous Integration (CI) tests are currently passing. CI tests verify correct operation of YOLOv5 training ([train.py](https://github.com/ultralytics/yolov5/blob/master/train.py)), testing ([val.py](https://github.com/ultralytics/yolov5/blob/master/val.py)), inference ([detect.py](https://github.com/ultralytics/yolov5/blob/master/detect.py)) and export ([export.py](https://github.com/ultralytics/yolov5/blob/master/export.py)) on macOS, Windows, and Ubuntu every 24 hours and on every commit.

# %% [markdown]
# # Appendix
#
# Additional content below.

# %%
# YOLOv5 PyTorch HUB Inference (DetectionModels only)
import torch

model = torch.hub.load('ultralytics/yolov5', 'yolov5s', force_reload=True, trust_repo=True)  # or yolov5n - yolov5x6 or custom
im = 'https://ultralytics.com/images/zidane.jpg'  # file, Path, PIL.Image, OpenCV, nparray, list
results = model(im)  # inference
results.print()  # or .show(), .save(), .crop(), .pandas(), etc.
